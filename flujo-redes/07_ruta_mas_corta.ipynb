# %% [markdown]
# <a href="https://colab.research.google.com/github/hfelizzola/Investigaciones-de-Operaciones-I/blob/main/flujo-redes/07_ruta_mas_corta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ruta Más Corta

# %%
# !pip install gamspy --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.1/215.1 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.6/28.6 MB 62.1 MB/s eta 0:00:00

# %%
import numpy as np
import pandas as pd
from gamspy import Container, Set, Parameter, Variable, Sum, Sense, Model, Equation, Options, Alias

# %%
[i+1 for i in range(5)]
# Out:
# [1, 2, 3, 4, 5]

# %%
# Modelo Matemático

# Container
m = Container()

# Set
i = Set(m , name='i', records=[i+1 for i in range(5)])
j = Alias(m, name="j", alias_with=i)

# Variable
x = Variable(m, name="x", domain=[i,j], type="positive")

# Función objetivo
objetivo = 100*x[1,2] + 30*x[1,3] + 20*x[2,3] + 10*x[3,4] + 15*x[4,2] + 60*x[3,5] + 50*x[4,5]

# Equation
nodo1 = Equation(m , name="nodo1")
nodo1[...] = 1 - x[1,2] - x[1,3] == 0

nodo2 = Equation(m , name="nodo2")
nodo2[...] = x[1,2] + x[4,2] - x[2,3] == 0

nodo3 = Equation(m , name="nodo3")
nodo3[...] = x[1,3] + x[2,3] - x[3,4] - x[3,5] == 0

nodo4 = Equation(m , name="nodo4")
nodo4 = x[3,4] - x[4,2] - x[4,5] == 0

nodo5 = Equation(m , name="nodo5")
nodo5[...] = x[3,5] + x[4,5] - 1 == 0

modelo = Model(m, objective=objetivo,
               problem="LP", equations=[nodo1, nodo2, nodo3, nodo4, nodo5],
               sense=Sense.MIN, name="modelo")
modelo.solve()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3596948064.py in <cell line: 0>()
#      30 nodo5[...] = x[3,5] + x[4,5] - 1 == 0
#      31
# ---> 32 modelo = Model(m, objective=objetivo,
#      33                problem="LP", equations=[nodo1, nodo2, nodo3, nodo4, nodo5],
#      34                sense=Sense.MIN, name="modelo")
#
# /usr/local/lib/python3.12/dist-packages/gamspy/_model.py in __init__(self, container, name, description, problem, equations, sense, objective, matches, limited_variables, external_module)
#     313         assert self.container is not None
#     314         self._matches = matches
# --> 315         self.problem, self.sense = validation.validate_model(
#     316             equations, matches, problem, sense
#     317         )
#
# /usr/local/lib/python3.12/dist-packages/gamspy/_validation.py in validate_model(equations, matches, problem, sense)
#     455             for equation in equations
#     456         ):
# --> 457             raise ValueError(
#     458                 "`equations` must be an Iterable of Equation objects"
#     459             )
#
# ValueError: `equations` must be an Iterable of Equation objects
